# %% [markdown]
# # Carbon Capture Analysis

# %%
# imports

import pandas as pd
import os

# %%
# get data file
data_file = os.path.abspath(os.path.join(
    os.path.dirname(os.path.realpath("__file__")), 'data', 'all_data.csv'))

data_file
# Out:
# '/home/tori/wind/data/all_data.csv'

# %% [markdown]
# ### download file

# %%
import boto3

s3 = boto3.client('s3')

s3_bucket = 'tori-calculate-wind-power'

output_main = 'output'

remote_file_path = os.path.join(
    output_main, os.path.basename(data_file))

s3.download_file(s3_bucket, remote_file_path, data_file)

# %% [markdown]
# ### read file

# %%
df = pd.read_csv(data_file)

df
# Out:
#       lat     lon                       _id  power_output           sed  \
# 0    47.5   5.625  62cbfc68ecbad53f4c826df0  6.996238e+07  3.659140e+08
# 1    47.5   6.250  62cbfc68ecbad53f4c826df1  5.329525e+07  3.712206e+08
# 2    47.5   6.875  62cbfc68ecbad53f4c826df2  5.698384e+07  3.693674e+08
# 3    47.5   7.500  62cbfc68ecbad53f4c826df3  5.314857e+07  3.679251e+08
# 4    47.5   8.125  62cbfc68ecbad53f4c826df4  4.760734e+07  3.679031e+08
# ..    ...     ...                       ...           ...           ...
# 267  55.5  12.500  62cbfc68ecbad53f4c826efb  1.042729e+08  3.400824e+08
# 268  55.5  13.125  62cbfc68ecbad53f4c826efc  1.073190e+08  3.419602e+08
# 269  55.5  13.750  62cbfc68ecbad53f4c826efd  1.102178e+08  3.426282e+08
# 270  55.5  14.375  62cbfc68ecbad53f4c826efe  1.127804e+08  3.432044e+08
# 271  55.5  15.000  62cbfc68ecbad53f4c826eff  1.134480e+08  3.419170e+08
#
#      carbon_footprint  emissions_carbon_capture
# 0            0.714670              2.615077e+08
# ...

# %% [markdown]
# ## Power Output

# %%
import plotly.express as px

fig = px.density_mapbox(df, lat='lat', lon='lon', z='power_output', radius=3,
                        zoom=3, mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0}, title = "Data")
fig.show()
# Out:
# <div>                            <div id="e6e15cd4-4dfa-4e9b-81dd-7f1a27f0f959" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6e15cd4-4dfa-4e9b-81dd-7f1a27f0f959")) {                    Plotly.newPlot(                        "e6e15cd4-4dfa-4e9b-81dd-7f1a27f0f959",                        [{"coloraxis":"coloraxis","hovertemplate":"power_output=%{z}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.5,49.5,49.5,49.5,49.5,49.5,49.5,4
# ...

# %% [markdown]
# ## SED

# %%
import plotly.express as px

fig = px.density_mapbox(df, lat='lat', lon='lon', z='sed', radius=5,
                        zoom=3, mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0}, title = "Data")
fig.show()
# Out:
# <div>                            <div id="20cd3a17-a4dd-4c84-91c0-11a6dafea900" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20cd3a17-a4dd-4c84-91c0-11a6dafea900")) {                    Plotly.newPlot(                        "20cd3a17-a4dd-4c84-91c0-11a6dafea900",                        [{"coloraxis":"coloraxis","hovertemplate":"sed=%{z}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.5,49.5,49.5,49.5,49.5,49.5,49.5,49.5,49.5,
# ...

# %% [markdown]
# ## Carbon Footprint

# %%
import plotly.express as px

fig = px.density_mapbox(df, lat='lat', lon='lon', z='carbon_footprint', radius=20,
                        zoom=3, mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0}, title = "Data")
fig.show()
# Out:
# <div>                            <div id="cf3d2a91-6183-4998-aa34-7b59573f8410" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf3d2a91-6183-4998-aa34-7b59573f8410")) {                    Plotly.newPlot(                        "cf3d2a91-6183-4998-aa34-7b59573f8410",                        [{"coloraxis":"coloraxis","hovertemplate":"carbon_footprint=%{z}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.5,49.5,49.5,49.5,49.5,49.5,49
# ...

# %% [markdown]
# ## Emissions Carbon Capture

# %%
import plotly.express as px

fig = px.density_mapbox(df, lat='lat', lon='lon', z='emissions_carbon_capture', radius=20,
                        zoom=3, mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0}, title = "Data")
fig.show()
# Out:
# <div>                            <div id="7381275b-3e12-4dba-a325-a4cdb285df05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7381275b-3e12-4dba-a325-a4cdb285df05")) {                    Plotly.newPlot(                        "7381275b-3e12-4dba-a325-a4cdb285df05",                        [{"coloraxis":"coloraxis","hovertemplate":"emissions_carbon_capture=%{z}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,47.5,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,48.5,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.0,49.5,49.5,49.5,49.5,49.5
# ...
